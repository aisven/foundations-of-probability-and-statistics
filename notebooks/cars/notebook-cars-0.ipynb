# %% [markdown]
# # Notebook 0 | Visualization of the car distribution

# %%
from foundations_of_probability_and_statistics.cars.car_distribution import create_joint_car_distribution
from foundations_of_probability_and_statistics.cars.visualize_car_distribution import visualize_pmf_given_brand
from foundations_of_probability_and_statistics.cars.visualize_car_distribution import visualize_joint_car_distribution_in_histogram

import pandas as pd

# show all rows of data frames and series per default
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## The full joint distribution
#
# All 38 states with their probabilities, factorized as
# $$p(b, h, c) = p(b) \, p(h \mid b) \, p(c \mid b)$$

# %%
joint = create_joint_car_distribution()
joint
# Out:
# brand    horsepower  color
# VW       100         blue      0.0600
#                      gray      0.1500
#                      black     0.0900
#          200         blue      0.0300
#                      gray      0.0750
#                      black     0.0450
#          300         blue      0.0100
#                      gray      0.0250
#                      black     0.0150
# Porsche  300         green     0.0120
#                      blue      0.0240
#                      gray      0.0360
#                      black     0.0480
#          400         green     0.0120
#                      blue      0.0240
#                      gray      0.0360
#                      black     0.0480
#          500         green     0.0030
#                      blue      0.0060
#                      gray      0.0090
#                      black     0.0120
#          600         green     0.0015
#                      blue      0.0030
#                      gray      0.0045
# ...

# %% [markdown]
# ## Histogram of the joint distribution
#
# One bar per joint state, one hue per brand, shading from lighter to darker with horsepower.

# %%
joint_car_distribution_histogram_figure = visualize_joint_car_distribution_in_histogram()

# %% [markdown]
# ## The conditional PMF given brand
#
# One tile heatmap per brand, conditioned as
# $$p(h, c \mid b) = \frac{p(b, h, c)}{p(b)}$$

# %%
pmf_vw_figure = visualize_pmf_given_brand(brand="VW")

# %%
pmf_porsche_figure = visualize_pmf_given_brand(brand="Porsche")

# %%
pmf_ferrari_figure = visualize_pmf_given_brand(brand="Ferrari")
